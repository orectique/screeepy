# %%
a = 5
b = 6

# %%
c = 9
#this is a comment

# %% [markdown]
# # this is a markdown cell

# %%
def fun(a, b):
    if a == 5:
        return a + b
    return a - b

# %%
print(sum(a, b))
print(c**2)
